# %%
#python program to color set 1
color_set1={"blue","black","white","pink","yellow"}
color_set2={"green","pink","red","white"}
result=color_set1-color_set2
print("New color set=",result)
# Out:
# New color set= {'black', 'yellow', 'blue'}

# %%
#python program to color set 2
set1=set(input("enter color set 1:").split(","))
set2=set(input("enter color set 2:").split(","))
print("colors present in both sets:")
print(set1&set2)
# Out:
# enter color set 1:blue,black,white,green
# enter color set 2:red,white,yellow
# colors in both sets:
# {'white'}
